# %%
from pandas_datareader import data as wb
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pylab import rcParams
from textblob import TextBlob
from selenium import webdriver

# %%
adj_close_data = wb.DataReader('AAPL', data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
rcParams['figure.figsize'] = 15, 7
plt.plot(adj_close_data)
plt.title('Adjusted Close Price (USD)')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# -------------------------------------

# %%
adj_close_data['1995-1-05']
# Out:
# 1.2025251388549805

# %%
driver = webdriver.Firefox(executable_path='./geckodriver')

# %%
driver.get('https://finance.yahoo.com/news/brookfield-renewable-energy-partners-bep-100000676.html')

# %%
text = driver.find_elements_by_xpath('//article/div/p')

# %%
file = open('current_text.txt', 'w')

# %%
for elem in text:
    if elem.get_attribute('content')[:7] == '<a href':
        break
    file.write(elem.text+' ')
file.close()

# %%
file = open('current_text.txt', 'r')

# %%
driver.close()

# %%
blob = TextBlob(file.read())

# %%
file.close()

# %%
blob.sentiment.polarity
# Out:
# 0.29057971014492756

# %%
if blob.sentiment.polarity < 0:
    eval1 = 0
else:
    eval1 = 1

# %%
print(eval1)
# Out:
# 1

# %%
dict1 = {
    0 : 'Bad',
    1 : 'Good'
}

# %%
print('Article Sentiment Analysis Result: {0}.'.format(dict1.get(eval1)))
# Out:
# Article Sentiment Analysis Result: Good.
